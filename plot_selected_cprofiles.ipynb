# %% [markdown]
# ## Plot selected carbon profiles

# %% [markdown]
# Without bainite

# %%
# %matplotlib inline
# %run plot_cprofiles.py mart_FoFo_CCE -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py mart_FoFo_CCEpara -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py mart_FoFo_mu30e3 -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py mart_FoFo_mu20e3 -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py mart_FoFo_CCEortho -t 1e-1 1 10 100 1000 -m

# %% [markdown]
# With bainite

# %%
# %matplotlib inline
# %run plot_cprofiles.py coupled_FoFo_375_CCE -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py coupled_FoFo_375_CCE -t 1e-1 1 10 100 1000 6 -xlim -.5:0 -ylim -.1:2 -m

# %run plot_cprofiles.py coupled_FoFo_375_CCEpara -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py coupled_FoFo_375_CCEpara -t 1e-1 1 10 100 1000 -m -xlim -.5:0 -ylim -.1:2 -m

# %run plot_cprofiles.py coupled_FoFo_375_mu30e3 -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py coupled_FoFo_375_mu23e3 -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py coupled_FoFo_375_mu20e3 -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py coupled_FoFo_375_mu16e3 -t 1e-1 1 10 100 1000 -m
# %run plot_cprofiles.py coupled_FoFo_375_CCEortho -t 1e-1 1 10 100 1000 -m
