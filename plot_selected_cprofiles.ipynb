# %% [markdown]
# ## Plot selected carbon profiles

# %% [markdown]
# Without bainite

# %%
# %matplotlib inline
# %run plot_cprofiles.py mart_FoFo_CCE -s 19 -s 199 -s 1999 -m
# %run plot_cprofiles.py mart_FoFo_CCEortho -s 1 -s 19 -s 199 -s 1999 -m
# %run plot_cprofiles.py mart_FoFo_mu30e3 -s 1 -s 19 -s 199 -s 1999 -m
# %run plot_cprofiles.py mart_FoFo_mu20e3 -s 1 -s 19 -s 199 -m
# Out:
# [19, 199, 1999]
# [1, 19, 199, 1999]

# %% [markdown]
# With bainite

# %%
# %matplotlib inline
# %run plot_cprofiles.py coupled_FoFo_375_CCE -s 1 -s 19 -s 199 -s 119 -m
# %run plot_cprofiles.py coupled_FoFo_375_CCE -s 1 -s 19 -s 199 -xlim -.5:0 -ylim -.1:2 -s 119 -m

# %run plot_cprofiles.py coupled_FoFo_375_CCEortho -s 1 -s 19 -s 199 -s 1999 -xlim -1.16:0 -m

# %run plot_cprofiles.py coupled_FoFo_375_CCEpara -s 1 -s 19 -s 199 -m
# %run plot_cprofiles.py coupled_FoFo_375_CCE -s 1 -s 19 -s 199 -xlim -.5:0 -ylim -.1:2 -s 119 -m
# Out:
# [1, 19, 119, 199]
