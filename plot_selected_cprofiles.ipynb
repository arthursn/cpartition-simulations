# %% [markdown]
# ## Plot selected carbon profiles

# %% [markdown]
# Without bainite

# %%
# %matplotlib inline
# %run plot_cprofiles.py mart_FoFo_CCE --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py mart_FoFo_CCEpara --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py mart_FoFo_mu30e3 --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py mart_FoFo_mu20e3 --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py mart_FoFo_CCEortho --time 1e-1 1 10 100 1000 --mirror --show

# %% [markdown]
# With bainite

# %%
# %matplotlib inline
# %run plot_cprofiles.py coupled_FoFo_375_CCE --time 1e-1 1 10 100 1000 --mirror --show

# %run plot_cprofiles.py coupled_FoFo_375_CCEpara --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py coupled_FoFo_375_CCEpara --time 1e-1 1 10 100 1000 --xlim -.5 0 --ylim -.1 2 --tracking --mirror --show

# %run plot_cprofiles.py coupled_FoFo_375_mu30e3 --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py coupled_FoFo_375_mu23e3 --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py coupled_FoFo_375_mu20e3 --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py coupled_FoFo_375_mu16e3 --time 1e-1 1 10 100 1000 --mirror --show
# %run plot_cprofiles.py coupled_FoFo_375_CCEortho --time 1e-1 1 10 100 1000 --mirror --show
