# %% [markdown]
# ## Plot selected carbon profiles

# %% [markdown]
# Carbon partitioning considering carbides in martensite (muC = 20e3 kJ/mol)

# %%
# %run plot_cprofiles.py mart_FoFo_mu20e3_profiles.txt -e 50
# Out:
# mart_FoFo_mu20e3_profiles.txt
